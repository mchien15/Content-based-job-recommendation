# %%
import pandas as pd
import numpy as np
import random
import warnings
import random
import time
from clean import clean_txt
from sklearn.feature_extraction.text import TfidfVectorizer
from extract_feature import feature_extraction_job, feature_extraction_user
from utils import compute_similarity, get_applicant_id_info, get_recommendation
warnings.filterwarnings("ignore")

# %%
final_df_jobs = pd.read_csv('./clean_data/final_df_jobs.csv')
final_df_user = pd.read_csv('./clean_data/final_user_df')
combine_df_job = pd.read_csv('./data/Combined_Jobs_Final.csv')
df_job_view = pd.read_csv('./data/Job_Views.csv')
df_experience = pd.read_csv('./data/Experience.csv')
df_interest_position = pd.read_csv('./data/Positions_Of_Interest.csv')

# %%
i = random.randint(0, len(final_df_user))
random_applicant_id = final_df_user['Applicant.ID'][i]
feature_text = final_df_user['text'][i]
_ = get_applicant_id_info(random_applicant_id, df_job_view, df_experience, df_interest_position)
# Out:
# Applicant Id: 4901 đã bấm vào tin tức tuyển dụng trên website với
# Vị trí:
# Tên công ty tương ứng là:
# Thành phố tương ứng là:
# Vị trí có kinh nghiệm: Sales Associate và Fashion Software
# Vị trí mong muốn:

# %%
def get_scores(type):
    start_time = time.time()
    assert type in range(3)
    if type != 2:
        try:
            user_feature_vector = feature_extraction_user([feature_text], final_df_jobs, type)
            job_feature_vector, _ = feature_extraction_job(final_df_jobs, type=0)
            cosine_scores = compute_similarity(job_feature_vector, user_feature_vector)
            top = sorted(range(len(cosine_scores)), key=lambda i: cosine_scores[i], reverse=True)[:10]
            list_scores = [cosine_scores[i][0][0] for i in top]
            print(f"Time excution: {time.time() - start_time:.6f}s")
            return top, list_scores
        except:
            print(f"Applicant ID: {random_applicant_id} không để lại thông tin")
    else:
        top, list_scores = feature_extraction_user([feature_text], final_df_jobs, type)
        print(f"Time excution: {time.time() - start_time:.6f}s")
        return top, list_scores

# %%
top_tfidf, list_scores_tfidf = get_scores(0)
# Out:
# Time excution: 39.246296s

# %%
top_bow, list_scores_bow = get_scores(1)
# Out:
# Time excution: 40.521025s

# %%
top_knn, list_scores_knn = get_scores(2)
# Out:
# Time excution: 0.861355s

# %% [markdown]
# ### Top Recommendations sử dụng TF-IDF

# %%
get_recommendation(top_tfidf, combine_df_job, final_df_jobs, list_scores_tfidf, applicant_id=random_applicant_id)
# Out:
#       JobID                                              title  \
# 0  244968.0                Fashion Branding @ INTERVIEWING NOW
# 1  287666.0                Fashion Branding @ Proof Management
# 2  282446.0  Software Engineering Intern @ Freewave Technol...
# 3  314852.0   IT Help Desk - Part Time @ Vengroff Williams Inc
# 4  274390.0  Customer Service - Retail Branding @ PR Assistant
# 5  293355.0              Retail Branding @ Harper Pierce & Co.
# 6  282480.0              Retail Branding @ Harper Pierce & Co.
# 7  245152.0                    Fashion Branding @ PR assistant
# 8  318328.0  Sales Assistant with Fund Development Software...
# 9  306530.0  Administrative Assistant for a Fashion Service...
#
#                                             Position  \
# 0                                   Fashion Branding
# 1                                   Fashion Branding
# 2                        Software Engineering Intern
# 3                           IT Help Desk - Part Time
# 4                 Customer Service - Retail Branding
# 5                                    Retail Branding
# 6                                    Retail Branding
# 7                                   Fashion Branding
# 8  Sales Assistant with Fund Development Software...
\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nJunior...  Full-Time/Part-Time
# 1  Retail Sales Associate - Showroom Sales - Inte...  Full-Time/Part-Time
# 2  Retail Sales Associate - Showroom Sales - Inte...  Full-Time/Part-Time
# 3  Retail Sales Associate - Showroom Sales - Inte...  Full-Time/Part-Time
# 4  Retail Sales Associate - Showroom Sales - Inte...  Full-Time/Part-Time
# 5  \r\n\r\nSales Representative - Retail\r\n\r\n\...  Full-Time/Part-Time
# 6  \r\n\r\nSales Representative - Retail\r\n\r\n\...  Full-Time/Part-Time
# 7  \r\n\r\nSales Representative - Retail\r\n\r\n\...  Full-Time/Part-Time
# 8  \r\n\r\nSales Representative - Retail\r\n\r\n\...  Full-Time/Part-Time
# 9  \r\n\r\nSales Representative - Retail\r\n\r\n\...  Full-Time/Part-Time
#
#       score
# 0  0.397404
# 1  0.366252
# 2  0.366113
# 3  0.364268
# 4  0.361658
# 5  0.357573
# 6  0.357573
# 7  0.357573
# 8  0.357573
# 9  0.357573

# %% [markdown]
# ### Top Recommendations sử dụng KNN

# %%
get_recommendation(top_knn, combine_df_job, final_df_jobs, list_scores_knn, applicant_id=random_applicant_id)
# Out:
#       JobID                                              title  \
# 0  244968.0                Fashion Branding @ INTERVIEWING NOW
# 1  287666.0                Fashion Branding @ Proof Management
# 2  282446.0  Software Engineering Intern @ Freewave Technol...
# 3  314852.0   IT Help Desk - Part Time @ Vengroff Williams Inc
# 4  274390.0  Customer Service - Retail Branding @ PR Assistant
# 5  293355.0              Retail Branding @ Harper Pierce & Co.
# 6  282480.0              Retail Branding @ Harper Pierce & Co.
# 7  245152.0                    Fashion Branding @ PR assistant
# 8  318328.0  Sales Assistant with Fund Development Software...
# 9  306530.0  Administrative Assistant for a Fashion Service...
#
#                                             Position  \
# 0                                   Fashion Branding
# 1                                   Fashion Branding
# 2                        Software Engineering Intern
# 3                           IT Help Desk - Part Time
# 4                 Customer Service - Retail Branding
# 5                                    Retail Branding
# 6                                    Retail Branding
# 7                                   Fashion Branding
# 8  Sales Assistant with Fund Development Software...
# 9  Administrative Assistant for a Fashion Service...
#
#                        Company          City  \
# 0             INTERVIEWING NOW   Saint Louis
# 1             Proof Management       Detroit
# 2  Freewave Technologies, Inc.       Boulder
# 3        Vengroff Williams Inc      Sarasota
# 4                 PR Assistant  Grand Rapids
# 5          Harper Pierce & Co.   Saint Louis
# 6          Harper Pierce & Co.   Saint Louis
# 7                 PR assistant       Detroit
# 8                   OfficeTeam      Blue Ash
# 9                   OfficeTeam        Powell
#
#                                      Job.Description      Employment.Type  \
# 0  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nJunior...  Full-Time/Part-Time
# 1  \r\n\r\n\r\n\r\n\r\nJunior Fashion Branding - ...  Full-Time/Part-Time
# 2  \r\n\r\nThe Software Engineering Intern will b...               Intern
# 3  Primary Responsibilities:\r\n\r\n\r\n\r\n    S...            Part-Time
# 4  \r\n\r\n\r\n\r\n\r\nJunior Fashion Branding - ...  Full-Time/Part-Time
# 5  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nJunior...  Full-Time/Part-Time
# 6  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nJunior...  Full-Time/Part-Time
# 7  \r\n\r\n\r\n\r\n\r\nJunior Fashion Branding - ...  Full-Time/Part-Time
# 8  Ref ID: 03330-113249Classification: Secretary/...        Seasonal/Temp
# 9  Ref ID: 03350-125709Classification: Secretary/...        Seasonal/Temp
#
#       score
# 0  1.052872
# 1  1.155009
# 2  1.156566
# 3  1.163635
# 4  1.168570
# 5  1.169382
# 6  1.169382
# 7  1.180484
# 8  1.189985
# 9  1.193839
